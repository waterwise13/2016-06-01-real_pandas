# %%
# %load style/style.py
from IPython.core.display import HTML
css = open('style/style-table.css').read() + open('style/style-notebook.css').read()
HTML('<style>{}</style>'.format(css))

# %% [markdown]
# <div style=" color:black; text-shadow: 1px 1px brown; font-size:2em;  background:url(style/images/Lucerne3.jpg)">,
#     <h1 align="center">Scientific Python
#     <img src="style/images/kundalini_pythons_gold_outline.png" style="height:360px; align:center; " ></h1>
#     </div>

# %%
import pandas as pd
# %matplotlib inline

# %%
data = pd.DataFrame([range(0,256)]*256)

# %%
import matplotlib.pyplot as plt

image = plt.imshow(data)
plt.show()

# %%
image = plt.imshow(data.iloc[0:10,0:10],cmap='Greys_r')
image

# %%
import matplotlib.image as mpimg

# %%
img=mpimg.imread('stinkbug.png')
img.shape
# Out:
# (375, 500, 3)

# %%
img.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-5031efe24cc6> in <module>()
# ----> 1 img.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
plt.imshow(img[:,:,0],he)

# %%
img[::8,::8,1]
# Out:
# array([[ 0.40784314,  0.42352942,  0.43137255, ...,  0.44313726,
#          0.43529412,  0.42745098],
#        [ 0.42745098,  0.44705883,  0.45490196, ...,  0.47058824,
#          0.46666667,  0.45490196],
#        [ 0.45490196,  0.46666667,  0.47843137, ...,  0.49803922,
#          0.48627451,  0.47843137],
#        ...,
#        [ 0.43921569,  0.47058824,  0.49411765, ...,  0.51764709,
#          0.50980395,  0.46666667],
#        [ 0.47058824,  0.49411765,  0.49411765, ...,  0.49803922,
#          0.47450981,  0.45490196],
#        [ 0.42745098,  0.44705883,  0.4627451 , ...,  0.47450981,
#          0.46666667,  0.45490196]], dtype=float32)

# %%
plt.imshow(img[::8,::8,1])
