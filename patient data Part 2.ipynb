# %% [markdown]
#     Using the real data

# %%
import pandas as pd
import glob

# %%
# !pwd
# Out:
# /Users/Neuromancer/Documents/neuralcode/NeuralCode_2015_05_22/notebooks

# %%
rawfile = glob.glob('../*.xlsx')

# %%
rawfile
# Out:
# ['../Phase2_ParticipantInfo_demo_data.xlsx']

# %%
#using the ID column of the data as the unique id

rawfile = glob.glob('../*.xlsx')

df = pd.read_excel(rawfile[0],skiprows= 2,index_col = 0)
#remove the rows with NaN's
df = df.drop(['Low','High'],axis=0)
#have a look
for num, idx in enumerate(df.index):
    print(num, ': ',idx, '\n\n')
# Get rid of the row of NaN's at row 16, n.b. this deletes rows that are all NaN's
df = df.dropna(axis = 0,how = 'all')
for num, idx in enumerate(df.index):
    print(num, ': ',idx, '\n\n')
# Out:
# 0 :  8
#
#
# 1 :  31
#
#
# 2 :  56
#
#
# 3 :  140
#
#
# 4 :  148
#
#
# 5 :  185
#
#
# 6 :  176
#
#
# 7 :  227
#
#
# 8 :  233
#
#
# 9 :  279
#
#
# 10 :  318
#
#
# 11 :  378
#
#
# 12 :  505
#
#
# 13 :  506
#
#
# 14 :  570
#
#
# 15 :  619
#
#
# 16 :  nan
#
#
# 17 :  35
#
#
# 18 :  55
#
#
# 19 :  106
#
#
# 20 :  139
#
#
# 21 :  141
#
#
# 22 :  166
#
#
# 23 :  274
#
#
# 24 :  286
#
#
# 25 :  394
#
#
# 26 :  518
#
#
# 27 :  580
#
#
# 0 :  8
#
#
# 1 :  31
#
#
# 2 :  56
#
#
# 3 :  140
#
#
# 4 :  148
#
#
# 5 :  185
#
#
# 6 :  176
#
#
# 7 :  227
#
#
# 8 :  233
#
#
# 9 :  279
#
#
# 10 :  318
#
#
# 11 :  378
#
#
# 12 :  505
#
#
# 13 :  506
#
#
# 14 :  570
#
#
# 15 :  619
#
#
# 16 :  35
#
#
# 17 :  55
#
#
# 18 :  106
#
#
# 19 :  139
#
#
# 20 :  141
#
#
# 21 :  166
#
#
# 22 :  274
#
#
# 23 :  286
#
#
# 24 :  394
#
#
# 25 :  518
#
#
# 26 :  580

# %%
# Actually, let's fix this...

##Not a thorough fix but a quick tidy up of column names
#df.columns = [x.replace(' ','_') for x in df.columns]

# %%
names = df.columns

# %%
names
# Out:
# Index(['Age', 'Gender', 'Years Educ', 'Education Comp', 'Study disapline',
#        'Occupation', 'Hearing', 'Medication', 'Unnamed: 9',
#        'General Fam history?', 'Unnamed: 11', '1st degree Family history',
#        'Diagnosis', 'Personal History', 'Diagnosis.1', 'Medicated?', 'Smoker?',
#        'Frequency', 'Menstruation', 'Contraceptive'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ##How I build up code
#
# - __Start small and output to the cell__
#
# ```python
# df.columns
#
# Index(['Age', 'Gender', 'Years Educ', 'Education Comp', 'Study disapline', 'Occupation', 'Hearing', 'Medication', 'Unnamed: 9', 'General Fam history?', 'Unnamed: 11', '1st degree Family history', 'Diagnosis', 'Personal History', 'Diagnosis.1', 'Medicated?', 'Smoker?', 'Frequency', 'Menstruation', 'Contraceptive'], dtype='object')
# ```
# ---
# - __Try out a list comprehension to get started, still output to cell__
#
# ```python
# [x for x in df.columns]
# ['Age',
#  'Gender',
#  'Years Educ',
#  'Education Comp',
#  'Study disapline',
#  'Occupation',
#  'Hearing',
#  'Medication',
#  'Unnamed: 9',
#  'General Fam history?',
#  'Unnamed: 11',
#  '1st degree Family history',
#  'Diagnosis',
#  'Personal History',
#  'Diagnosis.1',
#  'Medicated?',
#  'Smoker?',
#  'Frequency',
#  'Menstruation',
#  'Contraceptive']
# ```
# ---
# - __Great! I'll save that to a list__
# ```python
# names = [x for x in df.columns]
# ```
# ---
# - __Now I want to take each item in 'names' and replace all non letters with something neutral__
#
# I tried to do this with list comprehension but I was getting confused - so a cuddly old 'for' loop worked.
# ```python
# import string
#
# cleanlist = []
#
# for word in names:
#     cleanlist.append(''.join([x.replace(' ','_') for x in ''.join([x for x in word if x not in string.punctuation])]))
# print(cleanlist)
#
# ['Age', 'Gender', 'Years_Educ', 'Education_Comp', 'Study_disapline', 'Occupation', 'Hearing', 'Medication', 'Unnamed_9', 'General_Fam_history', 'Unnamed_11', '1st_degree_Family_history', 'Diagnosis', 'Personal_History', 'Diagnosis1', 'Medicated', 'Smoker', 'Frequency', 'Menstruation', 'Contraceptive']
# ```
# ---
# - __That's still a bit confusing to read with a nested list comprehension (Why did I ever think that was going to be readable?)__
#
# It's better to be readable for debugging and future rewriting so I will change the nested list comprehension to something more obvious even though it will be more code.
#
# ```python
# import string
#
# cleanlist = []
#
# for word in names:
#     cleanlist.append(''.join([x for x in word if x not in string.punctuation]))
# print('cleanlist = {}'.format(cleanlist),'\n\n')
#
# nospace_list = []
#
# for word in cleanlist:
#     nospace_list.append(''.join([x.replace(' ','_') for x in word]))
# print('nospace_list = {}'.format(nospace_list))
#
# cleanlist = ['Age', 'Gender', 'Years Educ', 'Education Comp', 'Study disapline', 'Occupation', 'Hearing', 'Medication', 'Unnamed 9', 'General Fam history', 'Unnamed 11', '1st degree Family history', 'Diagnosis', 'Personal History', 'Diagnosis1', 'Medicated', 'Smoker', 'Frequency', 'Menstruation', 'Contraceptive']
#
#
# nospace_list = ['Age', 'Gender', 'Years_Educ', 'Education_Comp', 'Study_disapline', 'Occupation', 'Hearing', 'Medication', 'Unnamed_9', 'General_Fam_history', 'Unnamed_11', '1st_degree_Family_history', 'Diagnosis', 'Personal_History', 'Diagnosis1', 'Medicated', 'Smoker', 'Frequency', 'Menstruation', 'Contraceptive']
#
# ```
# ---
#
# __There is the possibility of using a lambda function.__
#
# ```python
# import string
#
# #Remove punctuation
# cleanlist = []
# temp_string = ''
#
# for word in names:
#     for letter in word:
#         if letter not in string.punctuation:
#             temp_string += letter
#
#     cleanlist.append(temp_string)
#     temp_string = ''
#
# print('cleanlist = {}'.format(cleanlist),'\n\n')
#
# #Replace spaces with '_'
#
# nospace_list = []
#
# despace = lambda word: word.replace(' ','_')
#
# for word in cleanlist:
#     nospace_list.append(despace(word))
#
# print('nospace_list = {}'.format(nospace_list),'\n\n')
#
# del(cleanlist, nospace_list, temp_string)
#
# cleanlist = ['Age', 'Gender', 'Years Educ', 'Education Comp', 'Study disapline', 'Occupation', 'Hearing', 'Medication', 'Unnamed 9', 'General Fam history', 'Unnamed 11', '1st degree Family history', 'Diagnosis', 'Personal History', 'Diagnosis1', 'Medicated', 'Smoker', 'Frequency', 'Menstruation', 'Contraceptive']
#
#
# nospace_list = ['Age', 'Gender', 'Years_Educ', 'Education_Comp', 'Study_disapline', 'Occupation', 'Hearing', 'Medication', 'Unnamed_9', 'General_Fam_history', 'Unnamed_11', '1st_degree_Family_history', 'Diagnosis', 'Personal_History', 'Diagnosis1', 'Medicated', 'Smoker', 'Frequency', 'Menstruation', 'Contraceptive']
# ```
# ---

# %%
import string

#Remove punctuation
cleanlist = []
temp_string = ''

for word in names:
    for letter in word:
        if letter not in string.punctuation:
            temp_string += letter
    
    cleanlist.append(temp_string)
    temp_string = ''
       
print('cleanlist = {}'.format(cleanlist),'\n\n')

#Replace spaces with '_'

nospace_list = []

for word in cleanlist:
    nospace_list.append(word.replace(' ','_'))
    
print('nospace_list = {}'.format(nospace_list),'\n\n')

del(cleanlist, nospace_list, temp_string)
# Out:
# cleanlist = ['Age', 'Gender', 'Years Educ', 'Education Comp', 'Study disapline', 'Occupation', 'Hearing', 'Medication', 'Unnamed 9', 'General Fam history', 'Unnamed 11', '1st degree Family history', 'Diagnosis', 'Personal History', 'Diagnosis1', 'Medicated', 'Smoker', 'Frequency', 'Menstruation', 'Contraceptive']
#
#
# nospace_list = ['Age', 'Gender', 'Years_Educ', 'Education_Comp', 'Study_disapline', 'Occupation', 'Hearing', 'Medication', 'Unnamed_9', 'General_Fam_history', 'Unnamed_11', '1st_degree_Family_history', 'Diagnosis', 'Personal_History', 'Diagnosis1', 'Medicated', 'Smoker', 'Frequency', 'Menstruation', 'Contraceptive']

# %%
import string

#Remove punctuation
cleanlist = []
temp_string = ''

for word in names:
    for letter in word:
        if letter not in string.punctuation:
            temp_string += letter
    
    cleanlist.append(temp_string)
    temp_string = ''
       
print('cleanlist = {}'.format(cleanlist),'\n\n')

#Replace spaces with '_'

nospace_list = []

despace = lambda word: word.replace(' ','_')

for word in cleanlist:
    nospace_list.append(despace(word))

#for word in cleanlist:
    #nospace_list.append(word.replace(' ','_'))
    
print('nospace_list = {}'.format(nospace_list),'\n\n')

del(cleanlist, temp_string)
# Out:
# cleanlist = ['Age', 'Gender', 'Years Educ', 'Education Comp', 'Study disapline', 'Occupation', 'Hearing', 'Medication', 'Unnamed 9', 'General Fam history', 'Unnamed 11', '1st degree Family history', 'Diagnosis', 'Personal History', 'Diagnosis1', 'Medicated', 'Smoker', 'Frequency', 'Menstruation', 'Contraceptive']
#
#
# nospace_list = ['Age', 'Gender', 'Years_Educ', 'Education_Comp', 'Study_disapline', 'Occupation', 'Hearing', 'Medication', 'Unnamed_9', 'General_Fam_history', 'Unnamed_11', '1st_degree_Family_history', 'Diagnosis', 'Personal_History', 'Diagnosis1', 'Medicated', 'Smoker', 'Frequency', 'Menstruation', 'Contraceptive']

# %%
df.columns = nospace_list

# %%
df
# Out:
#       Age  Gender  Years_Educ          Education_Comp  \
# ID
# 8    26.0  Female         6.0           Undergraduate
# 31   26.0       F         3.5          Secondary/TAFE
# 56   27.0    Male        13.0           Post Graduate
# 140  19.0       F         2.0               Secondary
# 148  19.0       M         2.0           Undergraduate
# 185  18.0       F         3.0               Secondary
# 176  18.0  Female         3.0               Secondary
# 227  19.0       F         3.0               Secondary
# 233  18.0       F         3.0               Secondary
# 279  33.0    Male        20.0           Post Graduate
# 318  20.0  Female         3.0               Secondary
# 378  19.0  Female         3.0               Secondary
# 505  27.0  Female         7.0           Undergraduate
# 506  25.0  Female        20.0           Undergraduate
# 570  26.0  Female        17.0                Graduate
# 619  30.0  Female         7.0           Undergraduate
# 35   37.0  Female        15.0                Graduate
# 55   20.0    Male         4.0               Secondary
# 106  18.0  Female        14.0               Secondary
# 139  18.0       M         3.0               Secondary
# 141  18.0       F         2.5               Secondary
# 166  19.0  Female         3.0               Secondary
# 274  27.0    Male        12.0                Graduate
# 286  18.0  Female         2.0               Secondary
# 394  18.0  Female         3.0               Secondary
# 518  22.0  Female         7.0               Secondary
# 580  29.0  Female         9.0  Undergraduate, Honours
#
#                        Study_disapline                        Occupation  \
# ID
# 8                Nutrition & Dietetics                 Dietician/Teacher
# 31               International studies                       Electrician
# 56                    Medical Research                   Research Fellow
# 140                 Psych and Forensic                           Student
# 148                         psychology                           student
# 185                         Psychology                           Butcher
# 176  Business (advertising)/Psychology                           Student
# 227                Forensic Psychology       Student & part time watress
# 233                         Psychology                        unemployed
# 279                   hearing research                       audiologist
# 318        Psychology Forensic Science                           Student
# 378                         Psychology                      Receptionist
# 505                      neuro science                           Student
# 506                         Psychology                           Student
# 570                         psychology                           student
# 619        Human Resources & Education               HR Projects Officer
# 35                Sensory neuroscience                        Researcher
# 55   International & Political studies                           Student
# 106                         Philosophy                           Student
# 139                Science(Psychology)                            Studen
# 141                 Psych and Forensic                           Student
# 166                         Psychology                           Student
# 274                                 IT  PhD Student / Software Developer
# 286   Criminology and Forensic Science                           Student
# 394        Psychology/forensic science                           cinemas
# 518                   Psychophysiology                 Medical Scientist
# 580             Cognitive Neuroscience              Student / Researcher
#
#     Hearing Medication                               Unnamed_9  \
# ID
# 8       No.        No.                                     NaN
# 31       no         no                                     NaN
# 56      No.        yes                                  zertex
# 140      No         No                                     NaN
# 148     No.         no                                     NaN
# 185     No.         No                                     NaN
# 176     No.       Yes.  The Pill, Ventolin as needed, Seritide
# 227     No.        Yes                     Pill(Levlin), xyzal
# 233     No.         No                                     NaN
# 279     No.        No.                                     NaN
# 318     No.        No.                                     NaN
# 378     No.        Yes                                    Pill
# 505     No.        No.                                     NaN
# 506     No.       Yes.                           Contraceptive
# 570     No.        No.                                     NaN
# 619     No.        No.                                     NaN
# 35      No.        No.                                     NaN
# 55      No.        No.                                     NaN
# 106     No.        Yes                                    Pill
# 139      no         no                                     NaN
# 141      no         no                                     NaN
# 166     No.        No.                         Pill(Femme tab)
# 274     No.        No.                                     NaN
# 286     No.        No.                                     NaN
# 394     No.        No.                                     NaN
# 518     No.        No.                                     NaN
# 580     No.        No.                                     NaN
#
#     General_Fam_history                                         Unnamed_11  \
# ID
# 8                  Yes.      Grandfather had Seasonal Affective Depression
# 31                   No                                                NaN
# 56                   No                                                NaN
# 140                 NaN                                                NaN
# 148                 Yes                                      Aunty Anxiety
# 185                 NaN                                                NaN
# 176                 Yes                          Schizophrenia, Depression
# 227                  No                                                NaN
# 233                 Yes                           Depression, bipolar, ASD
# 279                 No.                                                NaN
# 318                 No.                                                NaN
# 378                 Yes                                         Depression
# 505                Yes.                 Depression, Schizophrenia, Anxiety
# 506                 No.                                                NaN
# 570                Yes.                             Bipolar, schizophrenia
# 619                 Yes                                                NaN
# 35                 Yes.                          Paternal Major Depression
# 55                 Yes.  Mother's cousin on her father's side was diagn...
# 106                 Yes                                       Schizophenia
# 139                 NaN                                                NaN
# 141                 NaN                                                NaN
# 166                 Yes                                         Depression
# 274                  No                                                NaN
# 286                 Yes                                 Male cousin Autism
# 394                Yes.                           Brother is schizophrenic
# 518                 No.                                                NaN
# 580                 No.                                                NaN
#
#     1st_degree_Family_history  \
# ID
# 8                          No
# 31                        yes
# 56                        No.
# 140                        No
# 148                        No
# 185                        No
# 176                       No.
# 227                        No
# 233                      Yes.
# 279                        No
# 318                        No
# 378                       Yes
# 505                       Yes
# 506                        No
# 570                       Yes
# 619                      Yes.
# 35                       Yes.
# 55                        NaN
# 106                      Yes.
# 139                       yes
# 141                        no
# 166                        No
# 274                        No
# 286                     Check
# 394                       NaN
# 518                       NaN
# 580                       NaN
#
#                                            Diagnosis Personal_History  \
# ID
# 8                                                NaN               No
# 31                              Paternal cyclothymia               No
# 56                                               NaN              NaN
# 140                                              NaN               No
# 148                                              NaN               No
# 185                                              NaN              NA?
# 176                                              NaN               No
# 227                                              NaN               No
# 233                 Maternal and Paternal Depression              Yes
# 279                                              NaN               No
# 318                                              NaN              No.
# 378          Maternal Depression, Sibling Depression               No
# 505                 Mother Depression, Schizophrenia               No
# 506                                              NaN               No
# 570                                  Sibling Bipolar               No
# 619  brother ASD as adult, schizophrenia, depression               No
# 35                         Paternal Major Depression              Yes
# 55                                               NaN              NaN
# 106                           Paternal Schizophrenia              Yes
# 139                              Maternal depression              NaN
# 141                                              NaN              NaN
# 166                                              NaN               No
# 274                                              NaN               No
# 286                                              NaN              Yes
# 394                                              NaN              NaN
# 518                                              NaN              NaN
# 580                                              NaN              NaN
#
#                                             Diagnosis1  \
# ID
# 8                                                  NaN
# 31                                                 NaN
# 56                                                 NaN
# 140                                                NaN
# 148                                                NaN
# 185                                                NaN
# 176                                                NaN
# 227                                                NaN
# 233                                         Depression
# 279                                                NaN
# 318                                                NaN
# 378                                                NaN
# 505                                                NaN
# 506                                                NaN
# 570                                                NaN
# 619                                                NaN
# 35   Bipolar affective disorder(type 1)with psychot...
# 55                                                 NaN
# 106                                           Anorexia
# 139                                                NaN
# 141                                                NaN
# 166                                                NaN
# 274                                                NaN
# 286                                 Deression, Anxiety
# 394                                                NaN
# 518                                                NaN
# 580                                                NaN
#
#                   Medicated   Smoker  Frequency    Menstruation  \
# ID
# 8                        No       No        NaN               -
# 31                      NaN       No        NaN             NaN
# 56                      NaN       No        NaN             NaN
# 140                     NaN      NaN        NaN             NaN
# 148                     NaN  CONTACT        NaN             NaN
# 185                     NaN      NaN        NaN             NaN
# 176                     NaN       No        NaN         21 days
# 227                     NaN  CONTACT        NaN             NaN
# 233                      No  CONTACT        NaN             NaN
# 279                     NaN       No        NaN             NaN
# 318                     NaN       No        NaN           4days
# 378                     NaN       No        NaN          8 days
# 505                     NaN       No        NaN          1month
# 506                     NaN       No        NaN  Unknown(years)
# 570                     NaN       No        NaN          14days
# 619                     NaN       No        NaN           0days
# 35                      Yes       No        NaN             NaN
# 55                      NaN      NaN        NaN             NaN
# 106                      No       No        NaN           7days
# 139                     NaN      NaN        NaN             NaN
# 141                     NaN      NaN        NaN             NaN
# 166                     NaN       No        NaN          14days
# 274                     NaN       No        NaN             NaN
# 286  Yes(Zoloft sertraline)       No        NaN         5 weeks
# 394                     NaN      NaN        NaN             NaN
# 518                     NaN      NaN        NaN             NaN
# 580                     NaN       No        NaN          5 days
#
#             Contraceptive
# ID
# 8                     NaN
# 31                    NaN
# 56                    NaN
# 140                   NaN
# 148                   NaN
# 185                   NaN
# 176       Yes, Pill (Jaz)
# 227      Yes,Pill(Levlin)
# 233             yes, pill
# 279                   NaN
# 318                    No
# 378           Yes, Levlin
# 505             Yes, Pill
# 506    Yes, Depo Ralovera
# 570                    No
# 619                    No
# 35            Yes, Merina
# 55                    NaN
# 106             yes, pill
# 139                   NaN
# 141                   NaN
# 166  Yes, Pill(femme tab)
# 274                   NaN
# 286                    no
# 394                   NaN
# 518                   NaN
# 580                    No

# %%
#finally remove the NaN row
#df = df.dropna(axis = 0,how = 'all')
#and change the column names to something more useable
#df.columns = [x.replace(' ','_') for x in df.columns]
print(df)
# Out:
#       Age  Gender  Years_Educ          Education_Comp  \
# ID
# 8    26.0  Female         6.0           Undergraduate
# 31   26.0       F         3.5          Secondary/TAFE
# 56   27.0    Male        13.0           Post Graduate
# 140  19.0       F         2.0               Secondary
# 148  19.0       M         2.0           Undergraduate
# 185  18.0       F         3.0               Secondary
# 176  18.0  Female         3.0               Secondary
# 227  19.0       F         3.0               Secondary
# 233  18.0       F         3.0               Secondary
# 279  33.0    Male        20.0           Post Graduate
# 318  20.0  Female         3.0               Secondary
# 378  19.0  Female         3.0               Secondary
# 505  27.0  Female         7.0           Undergraduate
# 506  25.0  Female        20.0           Undergraduate
# 570  26.0  Female        17.0                Graduate
# 619  30.0  Female         7.0           Undergraduate
# 35   37.0  Female        15.0                Graduate
# 55   20.0    Male         4.0               Secondary
# 106  18.0  Female        14.0               Secondary
# 139  18.0       M         3.0               Secondary
# 141  18.0       F         2.5               Secondary
# 166  19.0  Female         3.0               Secondary
# 274  27.0    Male        12.0                Graduate
# 286  18.0  Female         2.0               Secondary
# 394  18.0  Female         3.0               Secondary
# 518  22.0  Female         7.0               Secondary
# 580  29.0  Female         9.0  Undergraduate, Honours
#
#                        Study_disapline                        Occupation  \
# ID
# 8                Nutrition & Dietetics                 Dietician/Teacher
# 31               International studies                       Electrician
# 56                    Medical Research                   Research Fellow
# 140                 Psych and Forensic                           Student
# 148                         psychology                           student
# 185                         Psychology                           Butcher
# 176  Business (advertising)/Psychology                           Student
# 227                Forensic Psychology       Student & part time watress
# 233                         Psychology                        unemployed
# 279                   hearing research                       audiologist
# 318        Psychology Forensic Science                           Student
# 378                         Psychology                      Receptionist
# 505                      neuro science                           Student
# 506                         Psychology                           Student
# 570                         psychology                           student
# 619        Human Resources & Education               HR Projects Officer
# 35                Sensory neuroscience                        Researcher
# 55   International & Political studies                           Student
# 106                         Philosophy                           Student
# 139                Science(Psychology)                            Studen
# 141                 Psych and Forensic                           Student
# 166                         Psychology                           Student
# 274                                 IT  PhD Student / Software Developer
# 286   Criminology and Forensic Science                           Student
# 394        Psychology/forensic science                           cinemas
# 518                   Psychophysiology                 Medical Scientist
# 580             Cognitive Neuroscience              Student / Researcher
#
#     Hearing Medication                               Unnamed_9  \
# ID
# 8       No.        No.                                     NaN
# 31       no         no                                     NaN
# 56      No.        yes                                  zertex
# 140      No         No                                     NaN
# 148     No.         no                                     NaN
# 185     No.         No                                     NaN
# 176     No.       Yes.  The Pill, Ventolin as needed, Seritide
# 227     No.        Yes                     Pill(Levlin), xyzal
# 233     No.         No                                     NaN
# 279     No.        No.                                     NaN
# 318     No.        No.                                     NaN
# 378     No.        Yes                                    Pill
# 505     No.        No.                                     NaN
# 506     No.       Yes.                           Contraceptive
# 570     No.        No.                                     NaN
# 619     No.        No.                                     NaN
# 35      No.        No.                                     NaN
# 55      No.        No.                                     NaN
# 106     No.        Yes                                    Pill
# 139      no         no                                     NaN
# 141      no         no                                     NaN
# 166     No.        No.                         Pill(Femme tab)
# 274     No.        No.                                     NaN
# 286     No.        No.                                     NaN
# 394     No.        No.                                     NaN
# 518     No.        No.                                     NaN
# 580     No.        No.                                     NaN
#
#     General_Fam_history                                         Unnamed_11  \
# ID
# 8                  Yes.      Grandfather had Seasonal Affective Depression
# 31                   No                                                NaN
# 56                   No                                                NaN
# 140                 NaN                                                NaN
# 148                 Yes                                      Aunty Anxiety
# 185                 NaN                                                NaN
# 176                 Yes                          Schizophrenia, Depression
# 227                  No                                                NaN
# 233                 Yes                           Depression, bipolar, ASD
# 279                 No.                                                NaN
# 318                 No.                                                NaN
# 378                 Yes                                         Depression
# 505                Yes.                 Depression, Schizophrenia, Anxiety
# 506                 No.                                                NaN
# 570                Yes.                             Bipolar, schizophrenia
# 619                 Yes                                                NaN
# 35                 Yes.                          Paternal Major Depression
# 55                 Yes.  Mother's cousin on her father's side was diagn...
# 106                 Yes                                       Schizophenia
# 139                 NaN                                                NaN
# 141                 NaN                                                NaN
# 166                 Yes                                         Depression
# 274                  No                                                NaN
# 286                 Yes                                 Male cousin Autism
# 394                Yes.                           Brother is schizophrenic
# 518                 No.                                                NaN
# 580                 No.                                                NaN
#
#     1st_degree_Family_history  \
# ID
# 8                          No
# 31                        yes
# 56                        No.
# 140                        No
# 148                        No
# 185                        No
# 176                       No.
# 227                        No
# 233                      Yes.
# 279                        No
# 318                        No
# 378                       Yes
# 505                       Yes
# 506                        No
# 570                       Yes
# 619                      Yes.
# 35                       Yes.
# 55                        NaN
# 106                      Yes.
# 139                       yes
# 141                        no
# 166                        No
# 274                        No
# 286                     Check
# 394                       NaN
# 518                       NaN
# 580                       NaN
#
#                                            Diagnosis Personal_History  \
# ID
# 8                                                NaN               No
# 31                              Paternal cyclothymia               No
# 56                                               NaN              NaN
# 140                                              NaN               No
# 148                                              NaN               No
# 185                                              NaN              NA?
# 176                                              NaN               No
# 227                                              NaN               No
# 233                 Maternal and Paternal Depression              Yes
# 279                                              NaN               No
# 318                                              NaN              No.
# 378          Maternal Depression, Sibling Depression               No
# 505                 Mother Depression, Schizophrenia               No
# 506                                              NaN               No
# 570                                  Sibling Bipolar               No
# 619  brother ASD as adult, schizophrenia, depression               No
# 35                         Paternal Major Depression              Yes
# 55                                               NaN              NaN
# 106                           Paternal Schizophrenia              Yes
# 139                              Maternal depression              NaN
# 141                                              NaN              NaN
# 166                                              NaN               No
# 274                                              NaN               No
# 286                                              NaN              Yes
# 394                                              NaN              NaN
# 518                                              NaN              NaN
# 580                                              NaN              NaN
#
#                                             Diagnosis1  \
# ID
# 8                                                  NaN
# 31                                                 NaN
# 56                                                 NaN
# 140                                                NaN
# 148                                                NaN
# 185                                                NaN
# 176                                                NaN
# 227                                                NaN
# 233                                         Depression
# 279                                                NaN
# 318                                                NaN
# 378                                                NaN
# 505                                                NaN
# 506                                                NaN
# 570                                                NaN
# 619                                                NaN
# 35   Bipolar affective disorder(type 1)with psychot...
# 55                                                 NaN
# 106                                           Anorexia
# 139                                                NaN
# 141                                                NaN
# 166                                                NaN
# 274                                                NaN
# 286                                 Deression, Anxiety
# 394                                                NaN
# 518                                                NaN
# 580                                                NaN
#
#                   Medicated   Smoker  Frequency    Menstruation  \
# ID
# 8                        No       No        NaN               -
# 31                      NaN       No        NaN             NaN
# 56                      NaN       No        NaN             NaN
# 140                     NaN      NaN        NaN             NaN
# 148                     NaN  CONTACT        NaN             NaN
# 185                     NaN      NaN        NaN             NaN
# 176                     NaN       No        NaN         21 days
# 227                     NaN  CONTACT        NaN             NaN
# 233                      No  CONTACT        NaN             NaN
# 279                     NaN       No        NaN             NaN
# 318                     NaN       No        NaN           4days
# 378                     NaN       No        NaN          8 days
# 505                     NaN       No        NaN          1month
# 506                     NaN       No        NaN  Unknown(years)
# 570                     NaN       No        NaN          14days
# 619                     NaN       No        NaN           0days
# 35                      Yes       No        NaN             NaN
# 55                      NaN      NaN        NaN             NaN
# 106                      No       No        NaN           7days
# 139                     NaN      NaN        NaN             NaN
# 141                     NaN      NaN        NaN             NaN
# 166                     NaN       No        NaN          14days
# 274                     NaN       No        NaN             NaN
# 286  Yes(Zoloft sertraline)       No        NaN         5 weeks
# 394                     NaN      NaN        NaN             NaN
# 518                     NaN      NaN        NaN             NaN
# 580                     NaN       No        NaN          5 days
#
#             Contraceptive
# ID
# 8                     NaN
# 31                    NaN
# 56                    NaN
# 140                   NaN
# 148                   NaN
# 185                   NaN
# 176       Yes, Pill (Jaz)
# 227      Yes,Pill(Levlin)
# 233             yes, pill
# 279                   NaN
# 318                    No
# 378           Yes, Levlin
# 505             Yes, Pill
# 506    Yes, Depo Ralovera
# 570                    No
# 619                    No
# 35            Yes, Merina
# 55                    NaN
# 106             yes, pill
# 139                   NaN
# 141                   NaN
# 166  Yes, Pill(femme tab)
# 274                   NaN
# 286                    no
# 394                   NaN
# 518                   NaN
# 580                    No

# %% [markdown]
#     The list comprehension probably deserves an explanation.
#     for every entry in the Gender column,
#     - the value is converted to lowercase
#     - the 0th letter is passed to the next function
#     - 'm' is changed to 'male'
#     - 'f' is changed to 'female'

# %%
df.Gender = [x.lower()[0].replace('m','male').replace('f','female') for x in df.Gender]
print(df.Gender)
# Out:
# ID
# 8      female
# 31     female
# 56       male
# 140    female
# 148      male
# 185    female
# 176    female
# 227    female
# 233    female
# 279      male
# 318    female
# 378    female
# 505    female
# 506    female
# 570    female
# 619    female
# 35     female
# 55       male
# 106    female
# 139      male
# 141    female
# 166    female
# 274      male
# 286    female
# 394    female
# 518    female
# 580    female
# Name: Gender, dtype: object

# %%
df.Hearing = [x.lower()[0].replace('n','no').replace('y','yes') for x in df.Hearing]
print(df.Hearing)
# Out:
# ID
# 8      no
# 31     no
# 56     no
# 140    no
# 148    no
# 185    no
# 176    no
# 227    no
# 233    no
# 279    no
# 318    no
# 378    no
# 505    no
# 506    no
# 570    no
# 619    no
# 35     no
# 55     no
# 106    no
# 139    no
# 141    no
# 166    no
# 274    no
# 286    no
# 394    no
# 518    no
# 580    no
# Name: Hearing, dtype: object

# %%
df.Medication = [x.lower()[0].replace('n','no').replace('y','yes') for x in df.Medication]
print(df.Medication)
# Out:
# ID
# 8       no
# 31      no
# 56     yes
# 140     no
# 148     no
# 185     no
# 176    yes
# 227    yes
# 233     no
# 279     no
# 318     no
# 378    yes
# 505     no
# 506    yes
# 570     no
# 619     no
# 35      no
# 55      no
# 106    yes
# 139     no
# 141     no
# 166     no
# 274     no
# 286     no
# 394     no
# 518     no
# 580     no
# Name: Medication, dtype: object

# %%
df.General_Fam_history

# %% [markdown]
# This column was a bit more challenging because of the NaN's. The list comprehension doesn't cope with the NaN's and rather than write out a whole loop with clauses to handle it, I decided to just select out the non-NaN values for the list comprehension __df['General_Fam_history?'].dropna()__ and replace the non-NaN values in the column __pd.notnull(df['General_Fam_history?'])__.
#
# ---
#
# df['General_Fam_history?'][pd.notnull(df['General_Fam_history?'])] = [x.lower()[0].replace('n','no').replace('y','yes') for x in df['General_Fam_history?'].dropna()]

# %%
df['General_Fam_history'][pd.notnull(df['General_Fam_history'])] \
= [x.lower()[0].replace('n','no').replace('y','yes') for x in df['General_Fam_history'].dropna()]
# Out:
# /Users/Neuromancer/anaconda/lib/python3.4/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df
# Out:
#       Age  Gender  Years_Educ          Education_Comp  \
# ID
# 8    26.0  female         6.0           Undergraduate
# 31   26.0  female         3.5          Secondary/TAFE
# 56   27.0    male        13.0           Post Graduate
# 140  19.0  female         2.0               Secondary
# 148  19.0    male         2.0           Undergraduate
# 185  18.0  female         3.0               Secondary
# 176  18.0  female         3.0               Secondary
# 227  19.0  female         3.0               Secondary
# 233  18.0  female         3.0               Secondary
# 279  33.0    male        20.0           Post Graduate
# 318  20.0  female         3.0               Secondary
# 378  19.0  female         3.0               Secondary
# 505  27.0  female         7.0           Undergraduate
# 506  25.0  female        20.0           Undergraduate
# 570  26.0  female        17.0                Graduate
# 619  30.0  female         7.0           Undergraduate
# 35   37.0  female        15.0                Graduate
# 55   20.0    male         4.0               Secondary
# 106  18.0  female        14.0               Secondary
# 139  18.0    male         3.0               Secondary
# 141  18.0  female         2.5               Secondary
# 166  19.0  female         3.0               Secondary
# 274  27.0    male        12.0                Graduate
# 286  18.0  female         2.0               Secondary
# 394  18.0  female         3.0               Secondary
# 518  22.0  female         7.0               Secondary
# 580  29.0  female         9.0  Undergraduate, Honours
#
#                        Study_disapline                        Occupation  \
# ID
# 8                Nutrition & Dietetics                 Dietician/Teacher
# 31               International studies                       Electrician
# 56                    Medical Research                   Research Fellow
# 140                 Psych and Forensic                           Student
# 148                         psychology                           student
# 185                         Psychology                           Butcher
# 176  Business (advertising)/Psychology                           Student
# 227                Forensic Psychology       Student & part time watress
# 233                         Psychology                        unemployed
# 279                   hearing research                       audiologist
# 318        Psychology Forensic Science                           Student
# 378                         Psychology                      Receptionist
# 505                      neuro science                           Student
# 506                         Psychology                           Student
# 570                         psychology                           student
# 619        Human Resources & Education               HR Projects Officer
# 35                Sensory neuroscience                        Researcher
# 55   International & Political studies                           Student
# 106                         Philosophy                           Student
# 139                Science(Psychology)                            Studen
# 141                 Psych and Forensic                           Student
# 166                         Psychology                           Student
# 274                                 IT  PhD Student / Software Developer
# 286   Criminology and Forensic Science                           Student
# 394        Psychology/forensic science                           cinemas
# 518                   Psychophysiology                 Medical Scientist
# 580             Cognitive Neuroscience              Student / Researcher
#
#     Hearing Medication                               Unnamed_9  \
# ID
# 8        no         no                                     NaN
# 31       no         no                                     NaN
# 56       no        yes                                  zertex
# 140      no         no                                     NaN
# 148      no         no                                     NaN
# 185      no         no                                     NaN
# 176      no        yes  The Pill, Ventolin as needed, Seritide
# 227      no        yes                     Pill(Levlin), xyzal
# 233      no         no                                     NaN
# 279      no         no                                     NaN
# 318      no         no                                     NaN
# 378      no        yes                                    Pill
# 505      no         no                                     NaN
# 506      no        yes                           Contraceptive
# 570      no         no                                     NaN
# 619      no         no                                     NaN
# 35       no         no                                     NaN
# 55       no         no                                     NaN
# 106      no        yes                                    Pill
# 139      no         no                                     NaN
# 141      no         no                                     NaN
# 166      no         no                         Pill(Femme tab)
# 274      no         no                                     NaN
# 286      no         no                                     NaN
# 394      no         no                                     NaN
# 518      no         no                                     NaN
# 580      no         no                                     NaN
#
#     General_Fam_history                                         Unnamed_11  \
# ID
# 8                   yes      Grandfather had Seasonal Affective Depression
# 31                   no                                                NaN
# 56                   no                                                NaN
# 140                 NaN                                                NaN
# 148                 yes                                      Aunty Anxiety
# 185                 NaN                                                NaN
# 176                 yes                          Schizophrenia, Depression
# 227                  no                                                NaN
# 233                 yes                           Depression, bipolar, ASD
# 279                  no                                                NaN
# 318                  no                                                NaN
# 378                 yes                                         Depression
# 505                 yes                 Depression, Schizophrenia, Anxiety
# 506                  no                                                NaN
# 570                 yes                             Bipolar, schizophrenia
# 619                 yes                                                NaN
# 35                  yes                          Paternal Major Depression
# 55                  yes  Mother's cousin on her father's side was diagn...
# 106                 yes                                       Schizophenia
# 139                 NaN                                                NaN
# 141                 NaN                                                NaN
# 166                 yes                                         Depression
# 274                  no                                                NaN
# 286                 yes                                 Male cousin Autism
# 394                 yes                           Brother is schizophrenic
# 518                  no                                                NaN
# 580                  no                                                NaN
#
#     1st_degree_Family_history  \
# ID
# 8                          No
# 31                        yes
# 56                        No.
# 140                        No
# 148                        No
# 185                        No
# 176                       No.
# 227                        No
# 233                      Yes.
# 279                        No
# 318                        No
# 378                       Yes
# 505                       Yes
# 506                        No
# 570                       Yes
# 619                      Yes.
# 35                       Yes.
# 55                        NaN
# 106                      Yes.
# 139                       yes
# 141                        no
# 166                        No
# 274                        No
# 286                     Check
# 394                       NaN
# 518                       NaN
# 580                       NaN
#
#                                            Diagnosis Personal_History  \
# ID
# 8                                                NaN               No
# 31                              Paternal cyclothymia               No
# 56                                               NaN              NaN
# 140                                              NaN               No
# 148                                              NaN               No
# 185                                              NaN              NA?
# 176                                              NaN               No
# 227                                              NaN               No
# 233                 Maternal and Paternal Depression              Yes
# 279                                              NaN               No
# 318                                              NaN              No.
# 378          Maternal Depression, Sibling Depression               No
# 505                 Mother Depression, Schizophrenia               No
# 506                                              NaN               No
# 570                                  Sibling Bipolar               No
# 619  brother ASD as adult, schizophrenia, depression               No
# 35                         Paternal Major Depression              Yes
# 55                                               NaN              NaN
# 106                           Paternal Schizophrenia              Yes
# 139                              Maternal depression              NaN
# 141                                              NaN              NaN
# 166                                              NaN               No
# 274                                              NaN               No
# 286                                              NaN              Yes
# 394                                              NaN              NaN
# 518                                              NaN              NaN
# 580                                              NaN              NaN
#
#                                             Diagnosis1  \
# ID
# 8                                                  NaN
# 31                                                 NaN
# 56                                                 NaN
# 140                                                NaN
# 148                                                NaN
# 185                                                NaN
# 176                                                NaN
# 227                                                NaN
# 233                                         Depression
# 279                                                NaN
# 318                                                NaN
# 378                                                NaN
# 505                                                NaN
# 506                                                NaN
# 570                                                NaN
# 619                                                NaN
# 35   Bipolar affective disorder(type 1)with psychot...
# 55                                                 NaN
# 106                                           Anorexia
# 139                                                NaN
# 141                                                NaN
# 166                                                NaN
# 274                                                NaN
# 286                                 Deression, Anxiety
# 394                                                NaN
# 518                                                NaN
# 580                                                NaN
#
#                   Medicated   Smoker  Frequency    Menstruation  \
# ID
# 8                        No       No        NaN               -
# 31                      NaN       No        NaN             NaN
# 56                      NaN       No        NaN             NaN
# 140                     NaN      NaN        NaN             NaN
# 148                     NaN  CONTACT        NaN             NaN
# 185                     NaN      NaN        NaN             NaN
# 176                     NaN       No        NaN         21 days
# 227                     NaN  CONTACT        NaN             NaN
# 233                      No  CONTACT        NaN             NaN
# 279                     NaN       No        NaN             NaN
# 318                     NaN       No        NaN           4days
# 378                     NaN       No        NaN          8 days
# 505                     NaN       No        NaN          1month
# 506                     NaN       No        NaN  Unknown(years)
# 570                     NaN       No        NaN          14days
# 619                     NaN       No        NaN           0days
# 35                      Yes       No        NaN             NaN
# 55                      NaN      NaN        NaN             NaN
# 106                      No       No        NaN           7days
# 139                     NaN      NaN        NaN             NaN
# 141                     NaN      NaN        NaN             NaN
# 166                     NaN       No        NaN          14days
# 274                     NaN       No        NaN             NaN
# 286  Yes(Zoloft sertraline)       No        NaN         5 weeks
# 394                     NaN      NaN        NaN             NaN
# 518                     NaN      NaN        NaN             NaN
# 580                     NaN       No        NaN          5 days
#
#             Contraceptive
# ID
# 8                     NaN
# 31                    NaN
# 56                    NaN
# 140                   NaN
# 148                   NaN
# 185                   NaN
# 176       Yes, Pill (Jaz)
# 227      Yes,Pill(Levlin)
# 233             yes, pill
# 279                   NaN
# 318                    No
# 378           Yes, Levlin
# 505             Yes, Pill
# 506    Yes, Depo Ralovera
# 570                    No
# 619                    No
# 35            Yes, Merina
# 55                    NaN
# 106             yes, pill
# 139                   NaN
# 141                   NaN
# 166  Yes, Pill(femme tab)
# 274                   NaN
# 286                    no
# 394                   NaN
# 518                   NaN
# 580                    No

# %% [markdown]
#
#     As I'm writing all these list comprehensions, it's occuring to me that I should make a function that does it.

# %%
[x.lower()[0].replace('m','male').replace('f','female').replace('n','False').replace('y','True') for x in df.Hearing]
# Out:
# ['False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False']

# %%
str(True)
# Out:
# 'True'

# %%
[str(x).lower() in ['yes','y','1','True'] for x in df.Medication]
# Out:
# [False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %% [markdown]
# #Using set( ) to show the unique values.

# %%
for name,number in zip([x for x in df],[set(df[x]) for x in df]):
    print(name,': ',number,'\n\n')
# Out:
# Age :  {33.0, 37.0, 18.0, 19.0, 20.0, 22.0, 25.0, 26.0, 27.0, 29.0, 30.0}
#
#
# Gender :  {'female', 'male'}
#
#
# Years_Educ :  {2.0, 3.5, 3.0, 4.0, 6.0, 7.0, 2.5, 9.0, 12.0, 13.0, 14.0, 15.0, 17.0, 20.0}
#
#
# Education_Comp :  {'Undergraduate', 'Graduate', 'Undergraduate, Honours', 'Post Graduate', 'Secondary', 'Secondary/TAFE'}
#
#
# Study_disapline :  {'Sensory neuroscience', 'Medical Research', 'psychology', 'International & Political studies', 'Psychology Forensic Science', 'Nutrition & Dietetics', 'neuro science', 'Philosophy', 'International studies', 'IT', 'Criminology and Forensic Science', 'Psychology/forensic science', 'Psych and Forensic', 'hearing research', 'Science(Psychology)', 'Business (advertising)/Psychology', 'Cognitive Neuroscience', 'Psychology', 'Human Resources & Education', 'Psychophysiology', 'Forensic Psychology'}
#
#
# Occupation :  {'Student', 'Medical Scientist', 'Studen', 'cinemas', 'Student & part time watress', 'Research Fellow', 'HR Projects Officer', 'student', 'Receptionist', 'Butcher', 'PhD Student / Software Developer', 'audiologist', 'Researcher', 'Dietician/Teacher', 'Electrician', 'Student / Researcher', 'unemployed'}
#
#
# Hearing :  {'no'}
#
#
# Medication :  {'no', 'yes'}
#
#
# Unnamed_9 :  {nan, 'zertex', 'Pill', 'The Pill, Ventolin as needed, Seritide', 'Pill(Femme tab)', 'Pill(Levlin), xyzal', 'Contraceptive'}
#
#
# General_Fam_history :  {nan, 'no', 'yes'}
#
#
# Unnamed_11 :  {nan, 'Depression', 'Schizophrenia, Depression', 'Schizophenia', 'Depression, Schizophrenia, Anxiety', 'Bipolar, schizophrenia', 'Male cousin Autism', 'Brother is schizophrenic', 'Depression, bipolar, ASD', 'Paternal Major Depression', "Mother's cousin on her father's side was diagnosed with schizophrenia. Great Grandmother on Mother's side had bipolar.", 'Grandfather had Seasonal Affective Depression', 'Aunty Anxiety'}
#
#
# 1st_degree_Family_history :  {nan, 'Check', 'No.', 'Yes.', 'Yes', 'No', 'no', 'yes'}
#
#
# Diagnosis :  {nan, 'Maternal and Paternal Depression', 'Mother Depression, Schizophrenia', 'Paternal Schizophrenia', 'Sibling Bipolar', 'brother ASD as adult, schizophrenia, depression', 'Paternal Major Depression', 'Paternal cyclothymia', 'Maternal Depression, Sibling Depression', 'Maternal depression'}
#
#
# Personal_History :  {nan, 'Yes', 'No', 'No.', 'NA?'}
#
#
# Diagnosis1 :  {nan, 'Bipolar affective disorder(type 1)with psychotic fearures', 'Anorexia', 'Deression, Anxiety', 'Depression'}
#
#
# Medicated :  {nan, 'Yes', 'No', 'Yes(Zoloft sertraline)'}
#
#
# Smoker :  {nan, 'CONTACT', 'No'}
#
#
# Frequency :  {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan}
#
#
# Menstruation :  {nan, '21 days', '-', 'Unknown(years)', '8 days', '1month', '5 days', '14days', '7days', '0days', '5 weeks', '4days'}
#
#
# Contraceptive :  {nan, 'Yes, Levlin', 'Yes,Pill(Levlin)', 'Yes, Depo Ralovera', 'Yes, Pill', 'yes, pill', 'Yes, Merina', 'no', 'Yes, Pill (Jaz)', 'No', 'Yes, Pill(femme tab)'}
