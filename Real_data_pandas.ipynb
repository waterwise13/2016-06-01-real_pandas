# %% [markdown]
# <div style=" color:black; text-shadow: 1px 1px brown; font-size:2em;  background:url(style/images/Lucerne3.jpg)">,
#     <h1 align="center">Scientific Python
#     <img src="style/images/kundalini_pythons_gold_outline.png" style="height:360px; align:center; " ></h1>
#     </div>

# %% [markdown]
# I have the libraries I use regularly imported automatically into notebooks. If you don't import the following libraries under these shortcuts -

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
from IPython.core.display import HTML
css = open('style/style-table.css').read() + open('style/style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %% [markdown]
# Pandas has a number of methods to import data. The data file is in .xlsx format so we'll use the .read_excel method. We'll also explicitly skip the first, second and fourth line because I know they are blank lines.

# %%
pd.read_excel('Phase2_ParticipantInfo_deident_data.xlsx')
# Out:
#    Phase 2 participant demographics Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0                               NaN        NaN        NaN         NaN
# 1                                ID        Age     Gender  Years Educ
# 2                               Low        NaN        NaN         NaN
# 3                                46         26     Female           6
# 4                                62         26          F         3.5
# 5                               131         27       Male          13
# 6                               180         19          F           2
# 7                               148         19          M           2
# 8                               237         18          F           3
# 9                               233         18     Female           3
# 10                              312         19          F           3
# 11                              295         18          F           3
# 12                              327         33       Male          20
# 13                              403         20     Female           3
# 14                              468         19     Female           3
# 15                              563         27     Female           7
# 16                              573         25     Female          20
# 17                              611         26     Female          17
# 18                              660         30     Female           7
# 19                              NaN        NaN        NaN         NaN
# 20                             High        NaN        NaN         NaN
# 21                               57         37     Female          15
# 22                               62         20       Male           4
# 23                              136         18     Female          14
# 24                              188         18          M           3
# 25                              157         18          F         2.5
# 26                              181         19     Female           3
# 27                              305         27       Male          12
# 28                              382         18     Female           2
# 29                              405         18     Female           3
# 30                              558         22     Female           7
# 31                              649         29     Female           9
#
#                 Unnamed: 4                         Unnamed: 5  \
# 0                      NaN                                NaN
# 1           Education Comp                    Study disapline
# 2                      NaN                                NaN
# 3            Undergraduate              Nutrition & Dietetics
# 4           Secondary/TAFE              International studies
# 5            Post Graduate                   Medical Research
# 6                Secondary                 Psych and Forensic
# 7            Undergraduate                         psychology
# 8                Secondary                         Psychology
# 9                Secondary  Business (advertising)/Psychology
# 10               Secondary                Forensic Psychology
# 11               Secondary                         Psychology
# 12           Post Graduate                   hearing research
# 13               Secondary        Psychology Forensic Science
# 14               Secondary                         Psychology
# 15           Undergraduate                      neuro science
# 16           Undergraduate                         Psychology
# 17                Graduate                         psychology
# 18           Undergraduate        Human Resources & Education
# 19                     NaN                                NaN
# 20                     NaN                                NaN
# 21                Graduate               Sensory neuroscience
# 22               Secondary  International & Political studies
# 23               Secondary                         Philosophy
# 24               Secondary                Science(Psychology)
# 25               Secondary                 Psych and Forensic
# 26               Secondary                         Psychology
# 27                Graduate                                 IT
# 28               Secondary   Criminology and Forensic Science
# 29               Secondary        Psychology/forensic science
# 30               Secondary                   Psychophysiology
# 31  Undergraduate, Honours             Cognitive Neuroscience
#
#                           Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# 0                                NaN        NaN         NaN
# 1                         Occupation    Hearing  Medication
# 2                                NaN        NaN         NaN
# 3                  Dietician/Teacher        No.         No.
# 4                        Electrician         no          no
# 5                    Research Fellow        No.         yes
# 6                            Student         No          No
# 7                            student        No.          no
# 8                            Butcher        No.          No
# 9                            Student        No.        Yes.
# 10       Student & part time watress        No.         Yes
# 11                        unemployed        No.          No
# 12                       audiologist        No.         No.
# 13                           Student        No.         No.
# 14                      Receptionist        No.         Yes
# 15                           Student        No.         No.
# 16                           Student        No.        Yes.
# 17                           student        No.         No.
# 18               HR Projects Officer        No.         No.
# 19                               NaN        NaN         NaN
# 20                               NaN        NaN         NaN
# 21                        Researcher        No.         No.
# 22                           Student        No.         No.
# 23                           Student        No.         Yes
# 24                            Studen         no          no
# 25                           Student         no          no
# 26                           Student        No.         No.
# 27  PhD Student / Software Developer        No.         No.
# 28                           Student        No.         No.
# 29                           cinemas        No.         No.
# 30                 Medical Scientist        No.         No.
# 31              Student / Researcher        No.         No.
#
#                                 Unnamed: 9          ...           \
# 0                                      NaN          ...
# 1                                      NaN          ...
# 2                                      NaN          ...
# 3                                      NaN          ...
# 4                                      NaN          ...
# 5                                   zertex          ...
# 6                                      NaN          ...
# 7                                      NaN          ...
# 8                                      NaN          ...
# 9   The Pill, Ventolin as needed, Seritide          ...
# 10                     Pill(Levlin), xyzal          ...
# 11                                     NaN          ...
# 12                                     NaN          ...
# 13                                     NaN          ...
# 14                                    Pill          ...
# 15                                     NaN          ...
# 16                           Contraceptive          ...
# 17                                     NaN          ...
# 18                                     NaN          ...
# 19                                     NaN          ...
# 20                                     NaN          ...
# 21                                     NaN          ...
# 22                                     NaN          ...
# 23                                    Pill          ...
# 24                                     NaN          ...
# 25                                     NaN          ...
# 26                         Pill(Femme tab)          ...
# 27                                     NaN          ...
# 28                                     NaN          ...
# 29                                     NaN          ...
# 30                                     NaN          ...
# 31                                     NaN          ...
#
#                                           Unnamed: 11  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3       Grandfather had Seasonal Affective Depression
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                       Aunty Anxiety
# 8                                                 NaN
# 9                           Schizophrenia, Depression
# 10                                                NaN
# 11                           Depression, bipolar, ASD
# 12                                                NaN
# 13                                                NaN
# 14                                         Depression
# 15                 Depression, Schizophrenia, Anxiety
# 16                                                NaN
# 17                             Bipolar, schizophrenia
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                          Paternal Major Depression
# 22  Mother's cousin on her father's side was diagn...
# 23                                       Schizophenia
# 24                                                NaN
# 25                                                NaN
# 26                                         Depression
# 27                                                NaN
# 28                                 Male cousin Autism
# 29                           Brother is schizophrenic
# 30                                                NaN
# 31                                                NaN
#
#                   Unnamed: 12  \
# 0                         NaN
# 1   1st degree Family history
# 2                         NaN
# 3                          No
# 4                         yes
# 5                         No.
# 6                          No
# 7                          No
# 8                          No
# 9                         No.
# 10                         No
# 11                       Yes.
# 12                         No
# 13                         No
# 14                        Yes
# 15                        Yes
# 16                         No
# 17                        Yes
# 18                       Yes.
# 19                        NaN
# 20                        NaN
# 21                       Yes.
# 22                        NaN
# 23                       Yes.
# 24                        yes
# 25                         no
# 26                         No
# 27                         No
# 28                      Check
# 29                        NaN
# 30                        NaN
# 31                        NaN
#
#                                         Unnamed: 13       Unnamed: 14  \
# 0                                               NaN               NaN
# 1                                         Diagnosis  Personal History
# 2                                               NaN               NaN
# 3                                               NaN                No
# 4                              Paternal cyclothymia                No
# 5                                               NaN               NaN
# 6                                               NaN                No
# 7                                               NaN                No
# 8                                               NaN               NA?
# 9                                               NaN                No
# 10                                              NaN                No
# 11                 Maternal and Paternal Depression               Yes
# 12                                              NaN                No
# 13                                              NaN               No.
# 14          Maternal Depression, Sibling Depression                No
# 15                 Mother Depression, Schizophrenia                No
# 16                                              NaN                No
# 17                                  Sibling Bipolar                No
# 18  brother ASD as adult, schizophrenia, depression                No
# 19                                              NaN               NaN
# 20                                              NaN               NaN
# 21                        Paternal Major Depression               Yes
# 22                                              NaN               NaN
# 23                           Paternal Schizophrenia               Yes
# 24                              Maternal depression               NaN
# 25                                              NaN               NaN
# 26                                              NaN                No
# 27                                              NaN                No
# 28                                              NaN               Yes
# 29                                              NaN               NaN
# 30                                              NaN               NaN
# 31                                              NaN               NaN
#
#                                           Unnamed: 15             Unnamed: 16  \
# 0                                                 NaN                     NaN
# 1                                           Diagnosis              Medicated?
# 2                                                 NaN                     NaN
# 3                                                 NaN                      No
# 4                                                 NaN                     NaN
# 5                                                 NaN                     NaN
# 6                                                 NaN                     NaN
# 7                                                 NaN                     NaN
# 8                                                 NaN                     NaN
# 9                                                 NaN                     NaN
# 10                                                NaN                     NaN
# 11                                         Depression                      No
# 12                                                NaN                     NaN
# 13                                                NaN                     NaN
# 14                                                NaN                     NaN
# 15                                                NaN                     NaN
# 16                                                NaN                     NaN
# 17                                                NaN                     NaN
# 18                                                NaN                     NaN
# 19                                                NaN                     NaN
# 20                                                NaN                     NaN
# 21  Bipolar affective disorder(type 1)with psychot...                     Yes
# 22                                                NaN                     NaN
# 23                                           Anorexia                      No
# 24                                                NaN                     NaN
# 25                                                NaN                     NaN
# 26                                                NaN                     NaN
# 27                                                NaN                     NaN
# 28                                 Deression, Anxiety  Yes(Zoloft sertraline)
# 29                                                NaN                     NaN
# 30                                                NaN                     NaN
# 31                                                NaN                     NaN
#
#    Unnamed: 17 Unnamed: 18     Unnamed: 19           Unnamed: 20
# 0          NaN         NaN             NaN                   NaN
# 1      Smoker?   Frequency    Menstruation         Contraceptive
# 2          NaN         NaN             NaN                   NaN
# 3           No         NaN               -                   NaN
# 4           No         NaN             NaN                   NaN
# 5           No         NaN             NaN                   NaN
# 6          NaN         NaN             NaN                   NaN
# 7      CONTACT         NaN             NaN                   NaN
# 8          NaN         NaN             NaN                   NaN
# 9           No         NaN         21 days       Yes, Pill (Jaz)
# 10     CONTACT         NaN             NaN      Yes,Pill(Levlin)
# 11     CONTACT         NaN             NaN             yes, pill
# 12          No         NaN             NaN                   NaN
# 13          No         NaN           4days                    No
# 14          No         NaN          8 days           Yes, Levlin
# 15          No         NaN          1month             Yes, Pill
# 16          No         NaN  Unknown(years)    Yes, Depo Ralovera
# 17          No         NaN          14days                    No
# 18          No         NaN           0days                    No
# 19         NaN         NaN             NaN                   NaN
# 20         NaN         NaN             NaN                   NaN
# 21          No         NaN             NaN           Yes, Merina
# 22         NaN         NaN             NaN                   NaN
# 23          No         NaN           7days             yes, pill
# 24         NaN         NaN             NaN                   NaN
# 25         NaN         NaN             NaN                   NaN
# 26          No         NaN          14days  Yes, Pill(femme tab)
# 27          No         NaN             NaN                   NaN
# 28          No         NaN         5 weeks                    no
# 29         NaN         NaN             NaN                   NaN
# 30         NaN         NaN             NaN                   NaN
# 31          No         NaN          5 days                    No
#
# [32 rows x 21 columns]

# %%
pd.read_excel('Phase2_ParticipantInfo_demo_data.xlsx',skiprows=[0,1,3])

# %% [markdown]
# That looks alright, there are still a few problems but we'll deal with them when the data is in a Pandas DataFrame. I'll now read that data into a variable called 'df1' - We just saw the output of calling the read_excel method on the data file but if we want to work with it, it needs to be stored in a variable like this-

# %%
df1 = pd.read_excel('../Phase2_ParticipantInfo_demo_data.xlsx')

# %%
df1['Phase 2 participant demographics'] = replace

# %%
df1

# %%
2 + pd.np.random.randint(100)

# %%
replace = []
for x in df1['Phase 2 participant demographics']:
    try:
        replace.append(x + pd.np.random.randint(100)) 
    except:
        replace.append(x)

# %%
replace

# %%
df1 = pd.read_excel('../Phase2_ParticipantInfo_demo_data.xlsx',skiprows=[0,1,3])

# %%
df1['Patient ID'] = range(1,(df1.shape[0])+1)

# %%
df1.to_excel('Phase2_ParticipantInfo_deident_data.xlsx')

# %%
pd.read_excel('Phase2_ParticipantInfo_deident_data.xlsx')

# %% [markdown]
#  This command will drop any row that is all NaN's

# %%
df1.dropna(how = 'all',inplace=True)

# %% [markdown]
# I also want to drop the row at index 17 as it isn't a real row either.

# %%
df1.drop([17],inplace=True)

# %% [markdown]
# I then want to reset the index so it is isn't missing 16 and 17 (as they were removed when we dropped the rows)

# %%
df1.reset_index(drop = True,inplace = True)

# %%
df1

# %% [markdown]
# using the 'set' function I can better see what type of values are in the data for each row. It's

# %%
for name in df1.columns:
    print('{} --- {}'.format(name,set(df1[name])))
